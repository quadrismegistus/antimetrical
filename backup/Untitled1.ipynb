# %%
import sys; sys.path.insert(0,'/Users/ryan/github/cadence/')
import cadence as cd

# %%
txt="""
I caught this morning morning’s minion, king-
the of daylight’s dauphin, dapple-dawn-drawn Falcon, in his riding
Of the rolling level underneath him steady air, and striding
High there, how he rung upon the rein of a wimpling wing
In his ecstacy! then off, off forth on swing,
As a skate’s heel sweeps smooth on a bow-bend: the hurl and gliding
Rebuffed the big wind. My heart in hiding
Stirred for a bird,—the achieve of, the mastery of the thing!
"""

# %%
df=cd.parse(txt,linebreaks=True,phrasebreaks=False,only_best=True)
cd.show_parses(df)
# Out:
# Mapping do_parse_iter() [x1]: 100%|██████████████████████████████████████████| 8/8 [00:00<00:00, 52.66it/s]
# I <b>cáught</b> this <b>mór</b>ning <b>mór</b>ning<font style="color:darkred"><b>s</b></font> <font style="color:darkred"><b>mí</b></font>nion, <b>kíng</b>-
# <br/>the of <b>dáy</b><b>líght</b><font style="color:darkred">s</font> <b>dáup</b>hin, <b>dáp</b>ple-<b>dáwn</b>-<font style="color:darkred">dráwn</font> <b>Fál</b>con, <b>ín</b> his <b>rí</b>ding
# <br/>Of the <b>ról</b>ling <b>lé</b>vel <b>ún</b>der<b>néath</b> him <b>stéa</b>dy <b>áir</b>, and <b>strí</b>ding
# <br/><b>Hígh</b> there, <font style="color:darkred"><b>how</b></font> he <b>rúng</b> u<b>pón</b> the <b>réin</b> of a <b>wím</b>pling <b>wíng</b>
# <br/>In his <b>écs</b><font style="color:darkred">ta</font><font style="color:darkred">cy</font>! <b>thén</b> off, off <b>fórth</b> on <b>swíng</b>,
# ...

# %%
cd.to_lines(cd.parse('Of the rolling level underneath him steady air and striding'))
# Out:
# Mapping do_parse_iter() [x1]: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00, 13.70it/s]
#                                                                                                                                                                                                                                                                                                       is_stressed  ...  prom_strength
# stanza_i line_i linepart_i linepart_str                                       parse_rank is_troch parse_i parse            parse_str                                          combo_stress              combo_ipa                                          combo_i parse_is_bounded parse_bounded_by               ...
# ...

# %%
# cd.parse('As kíngfíshers cátch fíre drágonflíes dráw flámé')

# %%
cd.to_lines(df).query('parse_rank==1')
# Out:
#                                                                                                                                                                                                                                                                                                             is_stressed  ...  prom_strength
# stanza_i line_i linepart_i linepart_str                                       parse_rank is_troch parse_i parse             parse_str                                          combo_stress                   combo_ipa                                          combo_i parse_is_bounded parse_bounded_by               ...
# 1        1      1          I caught this morning morning’s minion, king-      1          0        1       wswswswssws       i|CAUGHT|this|MOR|ning|MOR|ning|S.MI*|nion|KING    U P U PU PU P PU P             aɪ 'kɑt ðɪs 'mɔːr.nɪŋ 'mɔːr.nɪŋ 'ɛs 'mɪ.njən 'kɪŋ  1       False                                        6  ...            3.0
# ...
