# %%
# Testing
fn='/Users/ryan/lltk_data/corpora/saintsbury/cadence_scan/en.blake.verse.ChadwyckPoetry.2535.pkl'

# %%
fn='/Users/ryan/github/antimetrical/data/Saintsbury/data.parse_ends.Saintsbury.100.dc'

# %%
import diskcache as dc
import pandas as pd
import cadence as cd
import lltk
C=lltk.load('Saintsbury')

# %%
i=0
with dc.Cache(fn) as d:
    for t in C.texts():
        if t.id in d:
            i+=1
            odf=d[t.id]
i
# Out:
# 3849

# %%
cd.setindex(odf)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                     *total  ...  prom_weight
# stanza_i line_i linepart_i parse_rank is_troch parse_i parse      parse_str                                      combo_stress     combo_ipa                                     combo_i parse_is_bounded parse_bounded_by parse_pos_i parse_pos word_i word_str   word_ipa_i word_ipa     syll_i syll_str syll_ipa syll_stress syll_weight parse_syll_i parse_syll          ...
# ...

# %%
import pandas as pd

# %%
pd.read_pickle(fn)
# Out:
#                                                                                                                                                                                                                            is_funcword  \
# stanza_i line_i line_str                                           linepart_i linepart_str                                    word_i word_str   word_ipa_i word_ipa      syll_i syll_str syll_ipa syll_stress syll_weight
# 1        1      O Rose thou art sick.                              1          O Rose thou art sick.                           1      O          1          oʊ            1      O        oʊ       U                                  1
#                                                                                                                               2      Rose       1          'roʊz         1      Rose     'roʊz    P                                  0
# ...
